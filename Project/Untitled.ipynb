# %%
import tensorflow as tf
from tensorflow import keras

# %%
model =tf.keras.models.load_model(".")

# %%
print(model.weights)
# Out:
# [<tf.Variable 'embedding_10/embeddings:0' shape=(2000, 128) dtype=float32, numpy=
# array([[ 0.00776685,  0.03228503,  0.01850051, ..., -0.0231741 ,
#         -0.00807062,  0.02106373],
#        [-0.02871876,  0.0125279 , -0.00905454, ..., -0.03240559,
#          0.04328406,  0.01859072],
#        [ 0.00566746,  0.03082928,  0.04161654, ..., -0.01234086,
#          0.02042902, -0.00969915],
#        ...,
#        [-0.01563267,  0.06045958, -0.04148808, ...,  0.0058377 ,
#         -0.06921685, -0.00064827],
#        [-0.02498599, -0.05258972,  0.03021818, ..., -0.00463691,
#         -0.03960968, -0.03463139],
#        [ 0.04115259, -0.05759334, -0.05430032, ...,  0.08021127,
#         -0.04251413,  0.05084539]], dtype=float32)>, <tf.Variable 'lstm_11/kernel:0' shape=(128, 784) dtype=float32, numpy=
# array([[ 3.7051987e-02,  1.0216104e-01, -7.1824178e-02, ...,
#         -5.7733495e-02, -5.8580771e-02,  2.6420593e-02],
#        [ 3.8988169e-02, -2.5396424e-03,  4.6607956e-02, ...,
# ...
